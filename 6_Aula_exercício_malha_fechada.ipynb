# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelodepaoli/Controle/blob/main/6_Aula_exerc%C3%ADcio_malha_fechada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install control
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.1/455.1 kB 7.4 MB/s eta 0:00:00
# ...

# %%
import control as ctl
import matplotlib.pyplot as plt
import numpy as np

# %%
R = 0.5
L = 1e-6
C = 1e-6

wn = 1/np.sqrt(L*C)
Kp=10*wn
Ki=2*wn
Kd=1*wn

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

C_s = ctl.tf([Kd,Kp,Ki],[1,0])
H_s = ctl.tf([1],[1])

G_q = C_s*P_q/(1+C_s*P_q*H_s)
G_i = C_s*P_i/(1+C_s*P_i*H_s)
G_vc = C_s*P_vc/(1+C_s*P_vc*H_s)

T_q, y_q = ctl.step_response(G_q, 1e-11)
T_i, y_i = ctl.step_response(G_i, 1e2)
T_vc, y_vc = ctl.step_response(G_vc, 10)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
#plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['tensão no capacitor'])
plt.grid()

# %%
R = 2
L = 1e-6
C = 1e-6

wn = 1/np.sqrt(L*C)
Kp=10*wn
Ki=2*wn
Kd=1*wn

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

C_s = ctl.tf([Kd,Kp,Ki],[1,0])
H_s = ctl.tf([1],[1])

G_q = C_s*P_q/(1+C_s*P_q*H_s)
G_i = C_s*P_i/(1+C_s*P_i*H_s)
G_vc = C_s*P_vc/(1+C_s*P_vc*H_s)

T_q, y_q = ctl.step_response(G_q, 1e-11)
T_i, y_i = ctl.step_response(G_i, 1e2)
T_vc, y_vc = ctl.step_response(G_vc, 10)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
#plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['tensão no capacitor'])
plt.grid()

# %%
R = 4
L = 1e-6
C = 1e-6

wn = 1/np.sqrt(L*C)
Kp=10*wn
Ki=2*wn
Kd=1*wn

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

C_s = ctl.tf([Kd,Kp,Ki],[1,0])
H_s = ctl.tf([1],[1])

G_q = C_s*P_q/(1+C_s*P_q*H_s)
G_i = C_s*P_i/(1+C_s*P_i*H_s)
G_vc = C_s*P_vc/(1+C_s*P_vc*H_s)

T_q, y_q = ctl.step_response(G_q, 1e-11)
T_i, y_i = ctl.step_response(G_i, 1e2)
T_vc, y_vc = ctl.step_response(G_vc, 10)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
#plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['tensão no capacitor'])
plt.grid()
