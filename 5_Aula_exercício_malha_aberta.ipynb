# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelodepaoli/Controle/blob/main/5_Aula_exerc%C3%ADcio_malha_aberta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install control
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.1/455.1 kB 6.9 MB/s eta 0:00:00
# ...

# %%
import control as ctl
import matplotlib.pyplot as plt
import numpy as np

# %%
R = 0.5
L = 1e-6
C = 1e-6
T_sim = 2.5e-5

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

T_q, y_q = ctl.step_response(P_q, T_sim)
T_i, y_i = ctl.step_response(P_i, T_sim)
T_vc, y_vc = ctl.step_response(P_vc, T_sim)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['degrau unitário', 'tensão no capacitor'])
plt.grid()

# %%
R = 2
L = 1e-6
C = 1e-6
T_sim = 2.5e-5

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

T_q, y_q = ctl.step_response(P_q, T_sim)
T_i, y_i = ctl.step_response(P_i, T_sim)
T_vc, y_vc = ctl.step_response(P_vc, T_sim)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['degrau unitário', 'tensão no capacitor'])
plt.grid()

# %%
R = 10
L = 1e-6
C = 1e-6
T_sim = 5e-5

P_q = ctl.tf([1/L], [1, R/L, 1/(L*C)])
P_i = ctl.tf([1/L, 0], [1, R/L, 1/(L*C)])
P_vc = ctl.tf([1/(L*C)], [1, R/L, 1/(L*C)])

T_q, y_q = ctl.step_response(P_q, T_sim)
T_i, y_i = ctl.step_response(P_i, T_sim)
T_vc, y_vc = ctl.step_response(P_vc, T_sim)

plt.figure()
plt.plot(T_q, y_q, 'b-')
plt.xlabel('tempo (s)')
plt.legend(['carga no capacitor'])
plt.grid()

plt.figure()
plt.plot(T_i, y_i, 'r-')
plt.xlabel('tempo (s)')
plt.legend(['corrente no circuito'])
plt.grid()

T_degrau = np.linspace(-1e-6, T_sim, 1000)
y_degrau = np.ones_like(T_degrau)
y_degrau[T_degrau<0] = 0

plt.figure()
plt.plot(T_degrau, y_degrau, 'b-')
plt.plot(T_vc, y_vc, 'k-')
plt.xlabel('tempo (s)')
plt.ylabel('tensão (V)')
plt.legend(['degrau unitário', 'tensão no capacitor'])
plt.grid()
